# %%
import pandas as pd

data_with_idio_mom = pd.read_parquet("data_with_idio_mom")
data_with_idio_mom
# Out:
#                date  permno   barrid  ret_crsp  spec_risk  PredBeta   mktrf  \
# 252      2004-08-06   10002  USAJAM1 -0.003623   0.264139  0.903500 -0.0159
# 253      2004-08-09   10002  USAJAM1 -0.009091   0.263822  0.914003  0.0002
# 254      2004-08-10   10002  USAJAM1  0.064832   0.266422  0.970975  0.0139
# 255      2004-08-11   10002  USAJAM1 -0.024124   0.263542  0.974759 -0.0029
# 256      2004-08-12   10002  USAJAM1 -0.025309   0.263449  0.976322 -0.0118
# ...             ...     ...      ...       ...        ...       ...     ...
# 32301996 2024-03-22   93436  USAA681 -0.011515   0.326648  1.827192 -0.0023
# 32301997 2024-03-25   93436  USAA681  0.010537   0.325666  1.816739 -0.0026
# 32301998 2024-03-26   93436  USAA681  0.029195   0.325681  1.800921 -0.0026
# 32301999 2024-03-27   93436  USAA681  0.012157   0.325041  1.801849  0.0088
# 32302000 2024-03-28   93436  USAA681 -0.022466   0.323660  1.810793  0.0010
#
# ...

# %%
data_with_idio_mom["date"].min()
# Out:
# Timestamp('1996-09-05 00:00:00')

# %%
data_with_idio_mom["date"].max()
# Out:
# Timestamp('2024-03-28 00:00:00')
